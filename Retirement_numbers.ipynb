# %% [markdown]
# <a href="https://colab.research.google.com/github/jshemm/RetirementPlanning/blob/main/Retirement_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')

#117 simulations from 1871-1987
Data = pd.read_csv("/content/gdrive/My Drive/Finance/sim_data(1).csv", index_col = "Row ID")
TotalSims = len(Data["Simulation Number"].unique())
EarlyYears = Data[Data["Year Number"] < 11]
Trouble = EarlyYears[EarlyYears["End Portfolio Value (In First Year Dollars)"] < 1000000]
ProblemSims = Trouble["Simulation Number"].unique()
NumProblemYears = len(ProblemSims)
PercProbYears = NumProblemYears / TotalSims * 100
Years = len(Data["Year Number"].unique())
Years
# Out:
# Mounted at /content/gdrive
# 35

# %%
PercProbYears
# Out:
# 8.547008547008547

# %%
Data.head()
# Out:
#         Simulation Number  Year Number  Start Year  End Year  Current Year  \
# Row ID
# 1.1                     1            1        1987      2021          1987
# 1.2                     1            2        1987      2021          1988
# 1.3                     1            3        1987      2021          1989
# 1.4                     1            4        1987      2021          1990
# 1.5                     1            5        1987      2021          1991
#
#         End Portfolio Value  End Portfolio Value (In First Year Dollars)  \
# Row ID
# 1.1              1893115.75                                   1819485.49
# 1.2              2067243.22                                   1898244.81
# 1.3              2365408.80                                   2064626.83
# 1.4              2312998.10                                   1910886.99
# 1.5              2789483.16                                   2246129.81
#
#         Is Out of Money?  Total Available Spend  \
# ...
